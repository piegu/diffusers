# %% [markdown]
# # text2img | Código mínimo para usar Stable Diffusion com🤗 Diffusers

# %% [markdown]
# - **Credit**: [Stable Diffusion with Diffusers](https://github.com/huggingface/notebooks/blob/main/diffusers/stable_diffusion.ipynb) (Hugging Face) and [Stable Diffusion with 🤗 Diffusers](https://github.com/fastai/diffusion-nbs/blob/master/stable_diffusion.ipynb) (fastai)
# - **Author**: Pierre GUILLOU
# - **Date**: 10/21/2022
# - **Blog post**: text2img | Código mínimo para usar Stable Diffusion com🤗 Diffusers

# %%
# !pip install -Uq diffusers transformers
# Out:
#      |████████████████████████████████| 255 kB 4.9 MB/s
#      |████████████████████████████████| 5.3 MB 68.2 MB/s
#      |████████████████████████████████| 163 kB 70.9 MB/s
#      |████████████████████████████████| 7.6 MB 66.9 MB/s

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %%
import torch
from diffusers import StableDiffusionPipeline
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", revision="fp16", torch_dtype=torch.float16).to(device)
# Out:
# Downloading:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.63k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/608M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/209 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/209 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/572 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/246M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/788 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.72G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/550 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/167M [00:00<?, ?B/s]
# ...

# %%
prompt = "a city street with lots of multicolored trees"

torch.manual_seed(1024)
pipe(prompt).images[0]
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FC3AEAFF7D0>

# %% [markdown]
# # END
